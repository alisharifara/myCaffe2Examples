# %%
import numpy as np

import skimage
import skimage.io as io
import skimage.transform

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimage

# %%
def display_image(img, title=None):
    plt.figure(figsize=(5,5))
    plt.imshow(img)
    plt.axis('on')
    title = title + ' \n shape: ' + str(img.shape)
    
    plt.title(title)
    plt.show()

# %%
# read the image
img = skimage.io.imread('./images/cat.jpg')

# convert it into float32
img = skimage.img_as_float32(img).astype(np.float32)

# %%
# color image cuz it has 3 channels (RGB)
# caffe2 2 expects to received image in the BGR format (wee need to flip the channel)
img.shape
# Out:
# (333, 500, 3)

# %%
display_image(img, 'original image - RGB')

# %%
# caffe2 and Opencv expects to received image in the BGR format (wee need to flip the channel)
img_bgr = img[:,:, (2, 1, 0)]
display_image(img_bgr, 'original image - BGR')

# %%
bgr_img.shape
# Out:
# (333, 500, 3)

# %%
# convert from HWC to CHW
img_bgr_chw = np.transpose(img_bgr, (2,0,1))

# it's in CHW
img_bgr_chw.shape
# Out:
# (3, 333, 500)

# %%
# image rotation is important when dealing with images from mobile devices
img_rotated = skimage.io.imread('./images/rotated_cat.jpg')
img_rotated = skimage.img_as_float32(img_rotated).astype(np.float32)

# %%
display_image(img_rotated, 'rotated')

# %%
img_rotated_90 = np.rot90(img_rotated)
display_image(img_rotated_90, 'rotated 1 time')

# %%
img_flipped = np.flipud(img_rotated_90)
display_image(img_flipped, 'flipped up side down')

# %%
# here is the right angle 
# when we work with images, all the images should be in the same pose (not one rotated, the other not, etc.)
img_rotated_90_3times = np.rot90(img_rotated, k=3)
display_image(img_rotated_90_3times, 'rotated 3 times')

# %%
# text recognition will fail if the source image is mirrored
img_mirrored = skimage.img_as_float(skimage.io.imread('./images/ambulance.jpg')).astype(np.float32)
display_image(img_mirrored, 'mirrored image')

# %%
img_mirrored_fliplr = np.fliplr(img_mirrored)
display_image(img_mirrored_fliplr, 'image fliped lr')
